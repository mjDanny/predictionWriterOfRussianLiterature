# %%
# !wget https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Out:
# --2024-05-27 22:40:06--  https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53012480 (51M) [application/x-tar]
# Saving to: ‘navec_hudlit_v1_12B_500K_300d_100q.tar’
#
# navec_hudlit_v1_12B 100%[===================>]  50.56M  44.6MB/s    in 1.1s
#
# 2024-05-27 22:40:08 (44.6 MB/s) - ‘navec_hudlit_v1_12B_500K_300d_100q.tar’ saved [53012480/53012480]

# %%
# !pip install navec
# Out:
# Collecting navec
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from navec) (1.25.2)
# Installing collected packages: navec
# Successfully installed navec-0.10.0

# %%
# Импорт необходимых библиотек
from navec import Navec
import keras
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense, BatchNormalization, Dropout
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Загрузка модели Navec
navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')

# Загрузка данных
data_path = keras.utils.get_file("russian_literature.zip", "https://storage.yandexcloud.net/academy.ai/russian_literature.zip")

# Разархивирование датасета
# !unzip -qo "{data_path}" -d ./dataset

# Определение списка классов
CLASS_LIST=["Bryusov", "Dostoevsky", "Gogol", "Gorky", "Tolstoy"]

# Сбор текстов по авторам
all_texts = {}
for author in CLASS_LIST:
    all_texts[author] = ''
    for path in glob.glob('./dataset/prose/{}/*.txt'.format(author)) +  glob.glob('./dataset/poems/{}/*.txt'.format(author)):
        with open(f'{path}', 'r', errors='ignore') as f:
            text = f.read()
        all_texts[author]  += ' ' + text.replace('\n', ' ')

# Токенизация текстов
embedding_dim = 300
max_words = 10000

tokenizer = Tokenizer(num_words=max_words,
                      filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
                      lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(all_texts.values())

# Преобразование текстов в последовательности токенов
seq_train = tokenizer.texts_to_sequences(all_texts.values())
seq_train_balance = [seq_train[cls][:40000] for cls in range(len(CLASS_LIST))]

# Функция для разбиения последовательностей на отрезки с использованием скользящего окна
WIN_SIZE = 1000
WIN_STEP = 100

def seq_split(sequence, win_size, step):
    return [sequence[i:i + win_size] for i in range(0, len(sequence) - win_size + 1, step)]

def seq_vectorize(seq_list, test_split, class_list, win_size, step):
    x_train, y_train, x_test, y_test =  [], [], [], []

    for class_item in class_list:
        cls = class_list.index(class_item)
        gate_split = int(len(seq_list[cls]) * (1-test_split))

        vectors_train = seq_split(seq_list[cls][:gate_split], win_size, step)
        vectors_test = seq_split(seq_list[cls][gate_split:], win_size, step)

        x_train += vectors_train
        x_test += vectors_test

        y_train += [keras.utils.to_categorical(cls, len(class_list))] * len(vectors_train)
        y_test += [keras.utils.to_categorical(cls, len(class_list))] * len(vectors_test)

    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

x_train, y_train, x_test, y_test = seq_vectorize(
    seq_train_balance,
    test_split=0.1,
    class_list=CLASS_LIST,
    win_size=WIN_SIZE,
    step=WIN_STEP
)

# Функция для отображения матрицы ошибок
def show_confusion_matrix(y_true, y_pred, class_labels):
    cm = confusion_matrix(np.argmax(y_true, axis=1), np.argmax(y_pred, axis=1), normalize='true')
    cm = np.around(cm, 3)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Матрица ошибок', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    plt.gca().images[-1].colorbar.remove()
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    fig.autofmt_xdate(rotation=45)
    plt.show()

    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# Создание матрицы эмбеддингов
word_index = tokenizer.word_index
embeddings_index = navec

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    if i < max_words:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# Создание модели
model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE))
model.add(BatchNormalization())
model.add(Dense(40, activation="relu"))
model.add(Dropout(0.6))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(len(CLASS_LIST), activation='softmax'))

# Установка весов слоя Embedding и заморозка
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False

# Разделение данных на обучающее и валидационное множества
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Определение коллбэка для сохранения лучшей модели
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Компиляция модели
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Обучение модели с использованием коллбэка
history = model.fit(x_train, y_train, epochs=50, batch_size=64, validation_data=(x_val, y_val), callbacks=[checkpoint])

# Сохранение весов модели
model.save_weights('pre_trained_model.h5')

# Загрузка лучшей модели
model.load_weights('best_model.h5')

# Оценка модели на тестовых данных
y_test_pred = model.predict(x_test)
show_confusion_matrix(y_test, y_test_pred, CLASS_LIST)
# Out:
# Downloading data from https://storage.yandexcloud.net/academy.ai/russian_literature.zip
# 21547079/21547079 [==============================] - 1s 0us/step
# error:  cannot create ./dataset/poems/Blok/╨б╤В╨╕╤Е╨╛╤В╨▓╨╛╤А╨╡╨╜╨╕╤П 1897-1903 ╨│╨│, ╨╜╨╡ ╨▓╨╛╤И╨╡╨┤╤И╨╕╨╡ ╨▓ ╨╛╤Б╨╜╨╛╨▓╨╜╨╛╨╡ ╤Б╨╛╨▒╤А╨░╨╜╨╕╨╡.txt
#         File name too long
# error:  cannot create ./dataset/prose/Gogol/╨Я╨╛╨▓╨╡╤Б╤В╤М ╨╛ ╤В╨╛╨╝, ╨║╨░╨║ ╨┐╨╛╤Б╤Б╨╛╤А╨╕╨╗╤Б╤П ╨Ш╨▓╨░╨╜ ╨Ш╨▓╨░╨╜╨╛╨▓╨╕╤З ╤Б ╨Ш╨▓╨░╨╜╨╛╨╝ ╨Э╨╕╨║╨╕╤Д╨╛╤А╨╛╨▓╨╕╤З╨╡╨╝.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Ф╨╛╨║╨╗╨░╨┤, ╨┐╤А╨╕╨│╨╛╤В╨╛╨▓╨╗╨╡╨╜╨╜╤Л╨╣ ╨┤╨╗╤П ╨║╨╛╨╜╨│╤А╨╡╤Б╤Б╨░ ╨╛ ╨╝╨╕╤А╨╡ ╨▓ ╨б╤В╨╛╨║╨│╨╛╨╗╤М╨╝╨╡.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Я╨╛╤З╨╡╨╝╤Г ╤Е╤А╨╕╤Б╤В╨╕╨░╨╜╤Б╨║╨╕╨╡ ╨╜╨░╤А╨╛╨┤╤Л ╨▓╨╛╨╛╨▒╤Й╨╡ ╨╕ ╨▓ ╨╛╤Б╨╛╨▒╨╡╨╜╨╜╨╛╤Б╤В╨╕ ╤А╤Г╤Б╤Б╨║╨╕╨╣ ╨╜╨░╤Е╨╛╨┤╤П╤В╤Б╤П ╤В╨╡╨┐╨╡╤А╤М ╨▓ ╨▒╨╡╨┤╤Б╤В╨▓╨╡╨╜╨╜╨╛╨╝ ╨┐╨╛╨╗╨╛╨╢╨╡╨╜╨╕╨╕.txt
#         File name too long
# Epoch 1/50
# 21/22 [===========================>..] - ETA: 0s - loss: 1.5789 - accuracy: 0.4516
# Epoch 1: val_accuracy improved from -inf to 0.61823, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 22/22 [==============================] - 9s 75ms/step - loss: 1.5571 - accuracy: 0.4566 - val_loss: 1.1332 - val_accuracy: 0.6182
# Epoch 2/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.1427 - accuracy: 0.9484
# Epoch 2: val_accuracy did not improve from 0.61823
# 22/22 [==============================] - 1s 25ms/step - loss: 0.1371 - accuracy: 0.9501 - val_loss: 0.9035 - val_accuracy: 0.6068
# Epoch 3/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0493 - accuracy: 0.9874
# Epoch 3: val_accuracy improved from 0.61823 to 0.62393, saving model to best_model.h5
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0478 - accuracy: 0.9879 - val_loss: 0.8918 - val_accuracy: 0.6239
# Epoch 4/50
# 22/22 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9950
# Epoch 4: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0266 - accuracy: 0.9950 - val_loss: 0.9700 - val_accuracy: 0.5783
# Epoch 5/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0152 - accuracy: 0.9985
# Epoch 5: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0152 - accuracy: 0.9986 - val_loss: 1.0392 - val_accuracy: 0.5783
# Epoch 6/50
# 22/22 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9950
# Epoch 6: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 1.1042 - val_accuracy: 0.5755
# Epoch 7/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0096 - accuracy: 0.9984
# Epoch 7: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 1.0215 - val_accuracy: 0.5812
# Epoch 8/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0067 - accuracy: 0.9993
# Epoch 8: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.9384 - val_accuracy: 0.5869
# Epoch 9/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0066 - accuracy: 0.9985
# Epoch 9: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.9208 - val_accuracy: 0.5726
# Epoch 10/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.62393
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.8305 - val_accuracy: 0.6097
# Epoch 11/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.62393 to 0.64387, saving model to best_model.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.6439
# Epoch 12/50
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0055 - accuracy: 0.9983
# Epoch 12: val_accuracy improved from 0.64387 to 0.68946, saving model to best_model.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.6077 - val_accuracy: 0.6895
# Epoch 13/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0041 - accuracy: 0.9992
# Epoch 13: val_accuracy improved from 0.68946 to 0.75783, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.5104 - val_accuracy: 0.7578
# Epoch 14/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0039 - accuracy: 0.9992
# Epoch 14: val_accuracy improved from 0.75783 to 0.82336, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.4174 - val_accuracy: 0.8234
# Epoch 15/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 15: val_accuracy improved from 0.82336 to 0.84046, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3743 - val_accuracy: 0.8405
# Epoch 16/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 16: val_accuracy improved from 0.84046 to 0.85755, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3469 - val_accuracy: 0.8575
# Epoch 17/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.85755 to 0.86610, saving model to best_model.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.8661
# Epoch 18/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0053 - accuracy: 0.9992
# Epoch 18: val_accuracy improved from 0.86610 to 0.87179, saving model to best_model.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.3065 - val_accuracy: 0.8718
# Epoch 19/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 19: val_accuracy improved from 0.87179 to 0.88889, saving model to best_model.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2945 - val_accuracy: 0.8889
# Epoch 20/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 20: val_accuracy improved from 0.88889 to 0.90028, saving model to best_model.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2890 - val_accuracy: 0.9003
# Epoch 21/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984
# Epoch 21: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.2798 - val_accuracy: 0.8974
# Epoch 22/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8917
# Epoch 23/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.8946
# Epoch 24/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2816 - val_accuracy: 0.8889
# Epoch 25/50
# 22/22 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8889
# Epoch 26/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.8860
# Epoch 27/50
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.8860
# Epoch 28/50
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.90028
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2778 - val_accuracy: 0.9003
# Epoch 29/50
# 20/22 [==========================>...] - ETA: 0s - loss: 8.0900e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.90028 to 0.90598, saving model to best_model.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 8.5430e-04 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9060
# Epoch 30/50
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 30: val_accuracy improved from 0.90598 to 0.90883, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9088
# Epoch 31/50
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 0.9992
# Epoch 31: val_accuracy did not improve from 0.90883
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.2514 - val_accuracy: 0.9060
# Epoch 32/50
# 19/22 [========================>.....] - ETA: 0s - loss: 5.8990e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.90883
# 22/22 [==============================] - 0s 15ms/step - loss: 5.8779e-04 - accuracy: 1.0000 - val_loss: 0.2540 - val_accuracy: 0.9031
# Epoch 33/50
# 20/22 [==========================>...] - ETA: 0s - loss: 6.8148e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.90883
# 22/22 [==============================] - 0s 17ms/step - loss: 7.8893e-04 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9031
# Epoch 34/50
# 21/22 [===========================>..] - ETA: 0s - loss: 7.0826e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy improved from 0.90883 to 0.91168, saving model to best_model.h5
# 22/22 [==============================] - 0s 21ms/step - loss: 6.9262e-04 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9117
# Epoch 35/50
# 21/22 [===========================>..] - ETA: 0s - loss: 9.4226e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy improved from 0.91168 to 0.91453, saving model to best_model.h5
# 22/22 [==============================] - 0s 21ms/step - loss: 9.9376e-04 - accuracy: 1.0000 - val_loss: 0.2480 - val_accuracy: 0.9145
# Epoch 36/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 0.9993
# Epoch 36: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.2610 - val_accuracy: 0.9088
# Epoch 37/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 0.9993
# Epoch 37: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.2939 - val_accuracy: 0.9088
# Epoch 38/50
# 21/22 [===========================>..] - ETA: 0s - loss: 9.7166e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 19ms/step - loss: 9.4584e-04 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9060
# Epoch 39/50
# 19/22 [========================>.....] - ETA: 0s - loss: 8.2429e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9088
# Epoch 40/50
# 22/22 [==============================] - ETA: 0s - loss: 4.8721e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 17ms/step - loss: 4.8721e-04 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.9088
# Epoch 41/50
# 18/22 [=======================>......] - ETA: 0s - loss: 5.8517e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 15ms/step - loss: 5.5514e-04 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9117
# Epoch 42/50
# 21/22 [===========================>..] - ETA: 0s - loss: 3.3139e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.91453
# 22/22 [==============================] - 0s 15ms/step - loss: 4.1002e-04 - accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9117
# Epoch 43/50
# 20/22 [==========================>...] - ETA: 0s - loss: 5.8265e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy improved from 0.91453 to 0.91738, saving model to best_model.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 6.4525e-04 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9174
# Epoch 44/50
# 20/22 [==========================>...] - ETA: 0s - loss: 4.4084e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.91738
# 22/22 [==============================] - 0s 15ms/step - loss: 4.2487e-04 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9174
# Epoch 45/50
# 20/22 [==========================>...] - ETA: 0s - loss: 6.1460e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy improved from 0.91738 to 0.92308, saving model to best_model.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 6.0429e-04 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9231
# Epoch 46/50
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.9993
# Epoch 46: val_accuracy improved from 0.92308 to 0.93447, saving model to best_model.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 0.2163 - val_accuracy: 0.9345
# Epoch 47/50
# 20/22 [==========================>...] - ETA: 0s - loss: 9.0781e-04 - accuracy: 0.9992
# Epoch 47: val_accuracy did not improve from 0.93447
# 22/22 [==============================] - 0s 15ms/step - loss: 8.7616e-04 - accuracy: 0.9993 - val_loss: 0.2131 - val_accuracy: 0.9345
# Epoch 48/50
# 20/22 [==========================>...] - ETA: 0s - loss: 4.0459e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.93447
# 22/22 [==============================] - 0s 15ms/step - loss: 3.8625e-04 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9345
# Epoch 49/50
# 20/22 [==========================>...] - ETA: 0s - loss: 3.2255e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.93447
# 22/22 [==============================] - 0s 16ms/step - loss: 3.2925e-04 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9345
# Epoch 50/50
# 19/22 [========================>.....] - ETA: 0s - loss: 3.0912e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy improved from 0.93447 to 0.93732, saving model to best_model.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 4.1454e-04 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9373
# 5/5 [==============================] - 0s 4ms/step
# Средняя точность распознавания:  87%
